# %%
from tfhe_benchmark import run_tfhe_benchmark

run_tfhe_benchmark()
# Out:
# TFHE Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse
# 0      TFHE                  0.043583                  0.023090  306.309229  \
# 1      TFHE                  0.034229                  0.017643  306.076521
# 2      TFHE                  0.054664                  0.029072  306.354354
# 3      TFHE                  0.047004                  0.025159  306.346621
# 4      TFHE                  0.047740                  0.026047  306.488089
#
#   Parameter Variation
# 0            standard
# 1               n=400
# 2               n=600
# 3      std_dev=0.0005
# 4       std_dev=0.002
