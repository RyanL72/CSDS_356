# %%
# Import benchmarks

from bfv_benchmark import run_bfv_benchmark
from ckks_benchmark import run_ckks_benchmark
from bgv_benchmark import run_bgv_benchmark

# %%
run_bgv_benchmark()
# Out:
# BGV Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0       BGV                  0.000117                  0.000023  360.324451
# 1       BGV                  0.000070                  0.000015  360.330564
# 2       BGV                  0.000212                  0.000038  360.316606
# 3       BGV                  0.000117                  0.000023  343.157258
# 4       BGV                  0.000118                  0.000021  373.964169
# 5       BGV                  0.000118                  0.000022  373.964169
# 6       BGV                  0.000118                  0.000022  332.341142
# 7       BGV                  0.000119                  0.000023  360.148614
# 8       BGV                  0.000116                  0.000022  360.448576
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# 5                t=17
# 6                t=61
# 7           sigma=2.0
# 8           sigma=5.0

# %%
run_bfv_benchmark()
# Out:
# BFV Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0       BFV                  0.000118                  0.000022  360.322076
# 1       BFV                  0.000071                  0.000015  360.325262
# 2       BFV                  0.000212                  0.000038  360.307871
# 3       BFV                  0.000117                  0.000022  343.152225
# 4       BFV                  0.000118                  0.000022  373.964169
# 5       BFV                  0.000118                  0.000022  373.964169
# 6       BFV                  0.000117                  0.000022  332.341072
# 7       BFV                  0.000118                  0.000022  360.155095
# 8       BFV                  0.000117                  0.000023  360.453853
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# 5                t=17
# 6                t=61
# 7           sigma=2.0
# 8           sigma=5.0

# %%
run_ckks_benchmark()
# Out:
# CKKS Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0      CKKS                  0.000154                  0.000032  273.931961
# 1      CKKS                  0.000090                  0.000019  273.930100
# 2      CKKS                  0.000273                  0.000059  273.933489
# 3      CKKS                  0.000151                  0.000031  320.029734
# 4      CKKS                  0.000152                  0.000032  194.993207
# 5      CKKS                  0.000152                  0.000032  194.997834
# 6      CKKS                  0.000150                  0.000032  320.039035
# 7      CKKS                  0.000151                  0.000031  273.932511
# 8      CKKS                  0.000150                  0.000032  273.936125
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# 5        scale=5000.0
# 6       scale=20000.0
# 7           sigma=2.0
# 8           sigma=5.0
