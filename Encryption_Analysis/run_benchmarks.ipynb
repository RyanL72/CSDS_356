# %%
# Import benchmarks

from bfv_benchmark import run_bfv_benchmark
from ckks_benchmark import run_ckks_benchmark
from bgv_benchmark import run_bgv_benchmark
from tfhe_benchmark import run_tfhe_benchmark

# %%
run_bgv_benchmark().to_csv('bgv.csv')
# Out:
# Files already downloaded and verified
# BGV Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0       BGV                  0.000264                  0.000078  360.319105
# 1       BGV                  0.000157                  0.000045  360.328776
# 2       BGV                  0.000475                  0.000140  360.316883
# 3       BGV                  0.000264                  0.000078  343.162014
# 4       BGV                  0.000265                  0.000077  373.964169
# 5       BGV                  0.000264                  0.000076  373.964169
# 6       BGV                  0.000266                  0.000078  332.341359
# 7       BGV                  0.000266                  0.000078  360.152087
# 8       BGV                  0.000261                  0.000077  360.457545
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# ...

# %%
run_bfv_benchmark().to_csv('bfv.csv')
# Out:
# Files already downloaded and verified
# BFV Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0       BFV                  0.000263                  0.000077  360.323434
# 1       BFV                  0.000157                  0.000045  360.321772
# 2       BFV                  0.000475                  0.000140  360.326698
# 3       BFV                  0.000263                  0.000078  343.149412
# 4       BFV                  0.000262                  0.000076  373.964169
# 5       BFV                  0.000262                  0.000076  373.964169
# 6       BFV                  0.000262                  0.000077  332.340995
# 7       BFV                  0.000263                  0.000077  360.153311
# 8       BFV                  0.000260                  0.000076  360.457781
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# ...

# %%
run_ckks_benchmark().to_csv('ckks.csv')
# Out:
# Files already downloaded and verified
# CKKS Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0      CKKS                  0.000257                  0.000041  273.931814
# 1      CKKS                  0.000163                  0.000025  273.930890
# 2      CKKS                  0.000442                  0.000072  273.932950
# 3      CKKS                  0.000260                  0.000041  320.030397
# 4      CKKS                  0.000255                  0.000041  194.994611
# 5      CKKS                  0.000256                  0.000041  194.998653
# 6      CKKS                  0.000260                  0.000041  320.039578
# 7      CKKS                  0.000258                  0.000041  273.932887
# 8      CKKS                  0.000257                  0.000041  273.929125
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# ...

# %%
run_tfhe_benchmark().to_csv('tfhe.csv')
# Out:
# Files already downloaded and verified
# TFHE Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0      TFHE                  0.032788                  0.012726  306.340145
# 1      TFHE                  0.026028                  0.009703  306.443308
# 2      TFHE                  0.039505                  0.015347  306.463752
# 3      TFHE                  0.032653                  0.012764  306.724410
# 4      TFHE                  0.032541                  0.012465  306.527887
#
#   Parameter Variation
# 0            standard
# 1               n=400
# 2               n=600
# 3      std_dev=0.0005
# 4       std_dev=0.002
