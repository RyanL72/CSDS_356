# %%
# Import benchmarks

from bfv_benchmark import run_bfv_benchmark
from ckks_benchmark import run_ckks_benchmark

# %%
run_bfv_benchmark()
# Out:
# BFV Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  ...     avg_mse  Parameter Variation
# 0       BFV                  0.000122  ...  360.340627             standard
# 1       BFV                  0.000071  ...  360.321330               n=1024
# 2       BFV                  0.000219  ...  360.337638               n=4096
# 3       BFV                  0.000120  ...  343.166964              q=32768
# 4       BFV                  0.000120  ...  373.964169             q=131072
# 5       BFV                  0.000121  ...  373.964169                 t=17
# 6       BFV                  0.000121  ...  332.341439                 t=61
# 7       BFV                  0.000122  ...  360.157804            sigma=2.0
# 8       BFV                  0.000120  ...  360.448055            sigma=5.0
#
# [9 rows x 5 columns]

# %%
run_ckks_benchmark()
# Out:
# CKKS Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0      CKKS                  0.000155                  0.000033  273.934381
# 1      CKKS                  0.000094                  0.000019  273.931541
# 2      CKKS                  0.000291                  0.000064  273.933116
# 3      CKKS                  0.000159                  0.000034  320.030368
# 4      CKKS                  0.000160                  0.000034  194.999655
# 5      CKKS                  0.000153                  0.000033  194.991573
# 6      CKKS                  0.000152                  0.000033  320.039521
# 7      CKKS                  0.000151                  0.000033  273.930405
# 8      CKKS                  0.000152                  0.000033  273.933043
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# 5        scale=5000.0
# ...
