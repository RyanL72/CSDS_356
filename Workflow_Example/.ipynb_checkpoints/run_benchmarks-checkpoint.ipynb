# %%
from bfv_benchmark import run_bfv_benchmark

run_bfv_benchmark()
# Out:
# Files already downloaded and verified
# BFV Benchmark Results:
#   Algorithm  avg_encrypt_time_per_100  avg_decrypt_time_per_100     avg_mse  \
# 0       BFV                  0.000140                  0.000031  360.337025
# 1       BFV                  0.000082                  0.000019  360.331618
# 2       BFV                  0.000244                  0.000051  360.327501
# 3       BFV                  0.000138                  0.000031  343.160969
# 4       BFV                  0.000137                  0.000029  373.964169
# 5       BFV                  0.000138                  0.000030  373.964169
# 6       BFV                  0.000136                  0.000030  332.341071
# 7       BFV                  0.000137                  0.000030  360.150064
# 8       BFV                  0.000135                  0.000030  360.455798
#
#   Parameter Variation
# 0            standard
# 1              n=1024
# 2              n=4096
# 3             q=32768
# 4            q=131072
# ...
